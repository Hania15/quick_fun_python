# %%
import pandas as pd

df = pd.read_csv('cars.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.head(20)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# ...

# %%
pd.options.display.max_rows = 45

# %%
pd.options.display.min_rows = None

# %%
pd
# Out:
# <module 'pandas' from '/Users/haniatrepkowska/anaconda3/lib/python3.11/site-packages/pandas/__init__.py'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.tail(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                        name
# 388          82     usa  chrysler lebaron medallion
# 389          82     usa              ford granada l
# ...

# %%
df['name']
# Out:
# 0              chevrolet chevelle malibu
# 1                      buick skylark 320
# 2                     plymouth satellite
# 3                          amc rebel sst
# 4                            ford torino
# 5                       ford galaxie 500
# 6                       chevrolet impala
# 7                      plymouth fury iii
# 8                       pontiac catalina
# 9                     amc ambassador dpl
# 10                   dodge challenger se
# 11                    plymouth 'cuda 340
# 12                 chevrolet monte carlo
# 13               buick estate wagon (sw)
# 14                 toyota corona mark ii
# 15                       plymouth duster
# 16                            amc hornet
# 17                         ford maverick
# 18                          datsun pl510
# 19                  vw 1131 deluxe sedan
# 20                           peugeot 504
# 21                           audi 100 ls
#                      ...
# ...

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df[['name','origin', 'model_year']]
# Out:
#                           name  origin  model_year
# 0    chevrolet chevelle malibu     usa          70
# 1            buick skylark 320     usa          70
# 2           plymouth satellite     usa          70
# 3                amc rebel sst     usa          70
# 4                  ford torino     usa          70
# ..                         ...     ...         ...
# 393            ford mustang gl     usa          82
# 394                  vw pickup  europe          82
# 395              dodge rampage     usa          82
# 396                ford ranger     usa          82
# 397             chevrolet s-10     usa          82
#
# [398 rows x 3 columns]

# %%
df.name
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397               chevrolet s-10
# Name: name, Length: 398, dtype: object

# %%
df.name.equals(df["name"])
# Out:
# True

# %%
pwd
# Out:
# '/Users/haniatrepkowska/Downloads/Course_Materials_ALL/Course_Materials_Part1'

# %%
cd
# Out:
# /Users/haniatrepkowska

# %%
cd Downloads
# Out:
# /Users/haniatrepkowska/Downloads

# %%
cd Course_Materials_ALL
# Out:
# /Users/haniatrepkowska/Downloads/Course_Materials_ALL

# %%
cd Course_Materials_Part2
# Out:
# /Users/haniatrepkowska/Downloads/Course_Materials_ALL/Course_Materials_Part2

# %%
cd Coding_Exercises
# Out:
# /Users/haniatrepkowska/Downloads/Course_Materials_ALL/Course_Materials_Part2/Coding_Exercises

# %%
summer = pd.read_csv('summer.csv', index_col = 'Athlete')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.iloc[[1,2,-10]]
# Out:
#                    Year    City      Sport           Discipline Country  \
# Athlete
# HERSCHMANN, Otto   1896  Athens   Aquatics             Swimming     AUT
# DRIVAS, Dimitrios  1896  Athens   Aquatics             Swimming     GRE
# AHMADOV, Emin      2012  London  Wrestling  Wrestling Freestyle     AZE
#
#                   Gender                       Event   Medal
# Athlete
# HERSCHMANN, Otto     Men              100M Freestyle  Silver
# DRIVAS, Dimitrios    Men  100M Freestyle For Sailors  Bronze
# AHMADOV, Emin        Men                    Wg 74 KG  Bronze

# %%
summer.iloc[-5:, :1]
# Out:
#                            Year
# Athlete
# JANIKOWSKI, Damian         2012
# REZAEI, Ghasem Gholamreza  2012
# TOTROV, Rustam             2012
# ALEKSANYAN, Artur          2012
# LIDBERG, Jimmy             2012

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.iloc[0, [0, 2, 5, 6]]
# Out:
# Year                1896
# Sport           Aquatics
# Gender               Men
# Event     100M Freestyle
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[:,4].equals(summer.Country)
# Out:
# True

# %%
summer.loc['MALOKINIS, Ioannis', ["Medal", "Event"]]
# Out:
# Medal                          Gold
# Event    100M Freestyle For Sailors
# Name: MALOKINIS, Ioannis, dtype: object

# %%
summer.loc['JANIKOWSKI, Damian':]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
summer.loc['JANIKOWSKI, Damian':'ALEKSANYAN, Artur', 'City':'Discipline']
# Out:
#                              City      Sport           Discipline
# Athlete
# JANIKOWSKI, Damian         London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          London  Wrestling  Wrestling Freestyle

# %%
summer.loc[['PAVIA, Automne','OCHAL, Glenn'],['Country','Sport']]
# Out:
#                Country   Sport
# Athlete
# PAVIA, Automne     FRA    Judo
# OCHAL, Glenn       USA  Rowing

# %%
summer = pd.read_csv('summer.csv')

# %%
summer
# Out:
#                                    Year    City      Sport  \
# Athlete
# HAJOS, Alfred                      1896  Athens   Aquatics
# HERSCHMANN, Otto                   1896  Athens   Aquatics
# DRIVAS, Dimitrios                  1896  Athens   Aquatics
# MALOKINIS, Ioannis                 1896  Athens   Aquatics
# CHASAPIS, Spiridon                 1896  Athens   Aquatics
# CHOROPHAS, Efstathios              1896  Athens   Aquatics
# HAJOS, Alfred                      1896  Athens   Aquatics
# ANDREOU, Joannis                   1896  Athens   Aquatics
# CHOROPHAS, Efstathios              1896  Athens   Aquatics
# NEUMANN, Paul                      1896  Athens   Aquatics
# PEPANOS, Antonios                  1896  Athens   Aquatics
# LANE, Francis                      1896  Athens  Athletics
# SZOKOLYI, Alajos                   1896  Athens  Athletics
# BURKE, Thomas                      1896  Athens  Athletics
# HOFMANN, Fritz                     1896  Athens  Athletics
# ...

# %%
summer.loc[[0, 5, 30000],['Athlete', 'Medal']]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
summer.reindex(index = [0, 5, 30000, 40000], columns = ['Athlete', 'Medal', 'Age'])
# Out:
#                      Athlete   Medal  Age
# 0              HAJOS, Alfred    Gold  NaN
# 5      CHOROPHAS, Efstathios  Bronze  NaN
# 30000       PAUTARAN, Maryna  Bronze  NaN
# 40000                    NaN     NaN  NaN

# %%
summer.loc[[0, 5, 30000],['Athlete', 'Medal']]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
# Select rows where 'Year' is greater than 2000 and 'Country' is 'USA'
summer[(summer['Year'] > 2000) & (summer['Country'] == 'USA')]
# Out:
#                                Year    City       Sport           Discipline  \
# Athlete
# PEIRSOL, Aaron                 2004  Athens    Aquatics             Swimming
# COUGHLIN, Natalie              2004  Athens    Aquatics             Swimming
# HANSEN, Brendan                2004  Athens    Aquatics             Swimming
# PHELPS, Michael                2004  Athens    Aquatics             Swimming
# CROCKER, Ian                   2004  Athens    Aquatics             Swimming
# COUGHLIN, Natalie              2004  Athens    Aquatics             Swimming
# JENSEN, Larsen                 2004  Athens    Aquatics             Swimming
# PEIRSOL, Aaron                 2004  Athens    Aquatics             Swimming
# HANSEN, Brendan                2004  Athens    Aquatics             Swimming
# BEARD, Amanda                  2004  Athens    Aquatics             Swimming
# PHELPS, Michael                2004  Athens    Aquatics             Swimming
# ...

# %%
summer.query('Year > 2000 and Country == "USA"')
# Out:
#                                Year    City       Sport           Discipline  \
# Athlete
# PEIRSOL, Aaron                 2004  Athens    Aquatics             Swimming
# COUGHLIN, Natalie              2004  Athens    Aquatics             Swimming
# HANSEN, Brendan                2004  Athens    Aquatics             Swimming
# PHELPS, Michael                2004  Athens    Aquatics             Swimming
# CROCKER, Ian                   2004  Athens    Aquatics             Swimming
# COUGHLIN, Natalie              2004  Athens    Aquatics             Swimming
# JENSEN, Larsen                 2004  Athens    Aquatics             Swimming
# PEIRSOL, Aaron                 2004  Athens    Aquatics             Swimming
# HANSEN, Brendan                2004  Athens    Aquatics             Swimming
# BEARD, Amanda                  2004  Athens    Aquatics             Swimming
# PHELPS, Michael                2004  Athens    Aquatics             Swimming
# ...

# %%
summer.query('Year > 2000 and Country == "USA"')
# Out:
#                                Year    City       Sport           Discipline  \
# Athlete
# PEIRSOL, Aaron                 2004  Athens    Aquatics             Swimming
# COUGHLIN, Natalie              2004  Athens    Aquatics             Swimming
# HANSEN, Brendan                2004  Athens    Aquatics             Swimming
# PHELPS, Michael                2004  Athens    Aquatics             Swimming
# CROCKER, Ian                   2004  Athens    Aquatics             Swimming
# COUGHLIN, Natalie              2004  Athens    Aquatics             Swimming
# JENSEN, Larsen                 2004  Athens    Aquatics             Swimming
# PEIRSOL, Aaron                 2004  Athens    Aquatics             Swimming
# HANSEN, Brendan                2004  Athens    Aquatics             Swimming
# BEARD, Amanda                  2004  Athens    Aquatics             Swimming
# PHELPS, Michael                2004  Athens    Aquatics             Swimming
# ...

# %%
print(summer['Year'].mean())
print(summer['Year'].median())
# Out:
# 1970.482785175678
# 1980.0

# %%
print(summer['Medal'].value_counts())
# Out:
# Medal
# Gold      10486
# Bronze    10369
# Silver    10310
# Name: count, dtype: int64

# %%
print(summer.sort_values(by='Year'))
# Out:
#                       Year    City       Sport           Discipline Country  \
# Athlete
# HAJOS, Alfred         1896  Athens    Aquatics             Swimming     HUN
# LOUNDRAS, Dimitrios   1896  Athens  Gymnastics          Artistic G.     GRE
# MITROPOULOS, Ioannis  1896  Athens  Gymnastics          Artistic G.     GRE
# BÖCKER, Konrad        1896  Athens  Gymnastics          Artistic G.     GER
# FLATOW, Alfred        1896  Athens  Gymnastics          Artistic G.     GER
# ...                    ...     ...         ...                  ...     ...
# CAMBAGE, Elizabeth    2012  London  Basketball           Basketball     AUS
# BISHOP, Abby          2012  London  Basketball           Basketball     AUS
# BATKOVIC, Suzy        2012  London  Basketball           Basketball     AUS
# CAMPBELL, Luke        2012  London      Boxing               Boxing     GBR
# LIDBERG, Jimmy        2012  London   Wrestling  Wrestling Freestyle     SWE
#
# ...

# %%
unique_values = summer.nunique()
print("Unique values in each column:")
print(unique_values)
# Out:
# Unique values in each column:
# Year           27
# City           22
# Sport          43
# Discipline     67
# Country       147
# Gender          2
# Event         666
# Medal           3
# dtype: int64

# %%
non_unique_values = summer.size - unique_values
print("\nNon-unique values in each column:")
print(non_unique_values)
# Out:
# Non-unique values in each column:
# Year          249293
# City          249298
# Sport         249277
# Discipline    249253
# Country       249173
# Gender        249318
# Event         248654
# Medal         249317
# dtype: int64

# %%
sprint_events = [summer['Event'].str.contains('Sprint', case=False, regex=True)]
print("Events containing 'Sprint':")
print(sprint_events)
# Out:
# Events containing 'Sprint':
# [Athlete
# HAJOS, Alfred                False
# HERSCHMANN, Otto             False
# DRIVAS, Dimitrios            False
# MALOKINIS, Ioannis           False
# CHASAPIS, Spiridon           False
#                              ...
# JANIKOWSKI, Damian           False
# REZAEI, Ghasem Gholamreza    False
# TOTROV, Rustam               False
# ALEKSANYAN, Artur            False
# LIDBERG, Jimmy               False
# Name: Event, Length: 31165, dtype: bool]
