# %%
import pandas as pd


df_joe_biden = pd.read_csv('president_approval_polls.csv')
df_donald_trump = pd.read_csv('president_approval_polls_historical.csv')

# %%
df_donald_trump.head()
# Out:
#    poll_id  pollster_id    pollster sponsor_ids   sponsors  \
# 0    74225          568      YouGov         352  Economist
# 1    74225          568      YouGov         352  Economist
# 2    74226           23         ARG         NaN        NaN
# 3    74226           23         ARG         NaN        NaN
# 4    74224         1528  AtlasIntel         NaN        NaN
#
#               display_name  pollster_rating_id     pollster_rating_name  \
# 0                   YouGov               391.0                   YouGov
# 1                   YouGov               391.0                   YouGov
# 2  American Research Group                 9.0  American Research Group
# 3  American Research Group                 9.0  American Research Group
# 4               AtlasIntel               546.0               AtlasIntel
#
#   fte_grade   methodology  ...  notes  \
# 0        B+  Online Panel  ...    NaN
# 1        B+  Online Panel  ...    NaN
# 2        C+    Live Phone  ...    NaN
# ...

# %%
df_joe_biden.head()
# Out:
#    poll_id  pollster_id      pollster sponsor_ids  \
# 0    85742         1102       Emerson         NaN
# 1    85750          399     Rasmussen        2006
# 2    85711          399     Rasmussen        2006
# 3    85709         1554  RMG Research         NaN
# 4    85708          399     Rasmussen        1744
#
#                                          sponsors       display_name  \
# 0                                             NaN    Emerson College
# 1  Matt Palumbo's Fact-Checking the Fact-Checkers  Rasmussen Reports
# 2  Matt Palumbo's Fact-Checking the Fact-Checkers  Rasmussen Reports
# 3                                             NaN       RMG Research
# 4               Miranda Devine's LAPTOP FROM HELL  Rasmussen Reports
#
#    pollster_rating_id pollster_rating_name fte_grade             methodology  \
# 0                  88      Emerson College        A-  IVR/Online Panel/Email
# 1                 277    Rasmussen Reports         B        IVR/Online Panel
# ...

# %%
df_together = df_połaczona = pd.concat([df_donald_trump, df_joe_biden], axis=0, ignore_index=True)
df_together
# Out:
#        poll_id  pollster_id         pollster sponsor_ids    sponsors  \
# 0        74225          568           YouGov         352   Economist
# 1        74225          568           YouGov         352   Economist
# 2        74226           23              ARG         NaN         NaN
# 3        74226           23              ARG         NaN         NaN
# 4        74224         1528       AtlasIntel         NaN         NaN
# ...        ...          ...              ...         ...         ...
# 14448    74248          241            Ipsos          71     Reuters
# 14449    74248          241            Ipsos          71     Reuters
# 14450    74327          568           YouGov        1213  Yahoo News
# 14451    74247          399        Rasmussen        1585     SLANTED
# 14452    74272         1189  Morning Consult         NaN         NaN
#
#                   display_name  pollster_rating_id     pollster_rating_name  \
# ...

# %%
missing_data= df_together.isnull().sum()
df_together
# Out:
#        poll_id  pollster_id         pollster sponsor_ids    sponsors  \
# 0        74225          568           YouGov         352   Economist
# 1        74225          568           YouGov         352   Economist
# 2        74226           23              ARG         NaN         NaN
# 3        74226           23              ARG         NaN         NaN
# 4        74224         1528       AtlasIntel         NaN         NaN
# ...        ...          ...              ...         ...         ...
# 14448    74248          241            Ipsos          71     Reuters
# 14449    74248          241            Ipsos          71     Reuters
# 14450    74327          568           YouGov        1213  Yahoo News
# 14451    74247          399        Rasmussen        1585     SLANTED
# 14452    74272         1189  Morning Consult         NaN         NaN
#
#                   display_name  pollster_rating_id     pollster_rating_name  \
# ...

# %%
statistics = df_together.describe()
statistics
# Out:
#             poll_id   pollster_id  pollster_rating_id  transparency_score  \
# count  14453.000000  14453.000000        14443.000000         1061.000000
# mean   65456.633017    747.317512          269.201759            6.918944
# std    11426.720588    456.710604          123.163262            2.504341
# min    49232.000000     23.000000            3.000000            1.000000
# 25%    56284.000000    399.000000          154.000000            5.000000
# 50%    65929.000000    568.000000          221.000000            7.000000
# 75%    75813.000000   1189.000000          391.000000            9.500000
# max    85750.000000   1842.000000          822.000000           10.000000
#
#        state  sponsor_candidate_id  sponsor_candidate  \
# count    0.0                   0.0                0.0
# mean     NaN                   NaN                NaN
# std      NaN                   NaN                NaN
# min      NaN                   NaN                NaN
# ...

# %%
groupby = df_together.groupby('politician').describe()
print(groupby)
# Out:
#               poll_id                                                         \
#                 count          mean          std      min       25%      50%
# politician
# Donald Trump  10017.0  59115.269043  7248.468636  49232.0  52313.00  57822.0
# Joe Biden      4436.0  79776.164788  3301.575976  74246.0  77175.75  79492.5
#
#                                 pollster_id              ...    no        \
#                    75%      max       count        mean  ...   75%   max
# politician                                               ...
# Donald Trump  66743.00  84157.0     10017.0  657.043526  ...  55.0  75.9
# Joe Biden     82478.25  85750.0      4436.0  951.166592  ...  55.0  65.0
#
#              alternate_answers                                             \
#                          count      mean       std  min  25%  50%     75%
# politician
# Donald Trump           10017.0  3.173142  3.153005  0.0  0.0  2.9  5.0000
# ...

# %%
statystyki_specyficzne = df_together[['pollster_rating_name', 'yes', 'no']].describe()
print(statystyki_specyficzne)
# Out:
#                 yes            no
# count  14453.000000  14453.000000
# mean      42.981778     52.541424
# std        4.186288      4.396875
# min       23.900000     28.000000
# 25%       40.000000     51.000000
# 50%       42.500000     53.000000
# 75%       45.000000     55.000000
# max       63.000000     75.900000

# %%
unikalne_wartosci = df_together['methodology'].unique()
print(unikalne_wartosci)
# Out:
# ['Online Panel' 'Live Phone' 'IVR/Online Panel' 'Probability Panel' nan
#  'Live Phone/Probability Panel' 'IVR/Text' 'Text-to-Web/Online Ad'
#  'Live Phone/Online Panel' 'IVR/Live Phone/Text-to-Web' 'IVR/Text-to-Web'
#  'IVR/Online Panel/Text-to-Web' 'IVR' 'Online Panel/Online Ad'
#  'IVR/Online Ad' 'IVR/Online Panel/Email' 'Online Panel/Text-to-Web'
#  'Live Phone/Online Panel/Text-to-Web' 'Live Phone/Text-to-Web'
#  'App Panel' 'Live Phone/Online Panel/Text'
#  'IVR/Live Phone/Online Panel/Text-to-Web' 'Text'
#  'Text-to-Web/Probability Panel/Online Ad' 'Probability Panel/Online Ad'
#  'IVR/Online Panel/Text-to-Web/Email'
#  'Live Phone/Online Panel/Text-to-Web/Mail-to-Web'
#  'Live Phone/Text-to-Web/Email/Face-to-Face' 'Online Ad'
#  'Live Phone/Online Panel/Text-to-Web/Email'
#  'IVR/Live Phone/Text/Online Panel/Email' 'IVR/Live Phone'
#  'IVR/Live Phone/Online Panel']

# %%
liczniki = df_together['partisan'].value_counts()
print(liczniki)
# Out:
# partisan
# REP    186
# DEM     78
# Name: count, dtype: int64
